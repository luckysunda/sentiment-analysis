# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
from sklearn.naive_bayes import MultinomialNB
from scipy import sparse

# %%
news_train = pd.read_csv('data/news-train.csv')
news_train = news_train[['title','description','label']]

# %%
news_test = pd.read_csv('data/news-train.csv')
news_test = news_test[['title','description']]

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer

# %%
#preprocessing Train data
import re
ps = PorterStemmer()
stops = set(stopwords.words("english"))

clean_train_title=[]
clean_train_description=[]

for review in news_train["title"]:
    review = re.sub("[^a-zA-Z]"," ", review)
    words = review.lower().split()
    words = [w for w in words if not w in stops]
    #words = [ps.stem(w) for w in words ]
    clean_train_title.append(" ".join(words))

    

for review in news_train["description"]:
    review = re.sub("[^a-zA-Z]"," ", review)
    words = review.lower().split()
    words = [w for w in words if not w in stops]
    #words = [ps.stem(w) for w in words ]
    clean_train_description.append(" ".join(words))

# %%
#preprocessing test data

clean_test_title=[]
clean_test_description=[]

for review in news_test["title"]:
    review = re.sub("[^a-zA-Z]"," ", review)
    words = review.lower().split()
    words = [w for w in words if not w in stops]
    words = [ps.stem(w) for w in words ]
    clean_test_title.append(" ".join(words))

    

for review in news_test["description"]:
    review = re.sub("[^a-zA-Z]"," ", review)
    words = review.lower().split()
    words = [w for w in words if not w in stops]
    words = [ps.stem(w) for w in words ]
    clean_test_description.append(" ".join(words))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
count_vec1 = TfidfVectorizer(stop_words='english')
count_vec2 = TfidfVectorizer(stop_words='english')
train_count2=count_vec2.fit_transform(clean_train_description)
train_count1=count_vec1.fit_transform(clean_train_title)
train_count=sparse.hstack((train_count1,train_count2))
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
from sklearn.cross_validation import KFold,cross_val_score
scores=cross_val_score(clf,train_count,news_train["label"],cv=10,scoring='accuracy')
# Out:
# /Users/sachinmittal/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
scores.mean()
# Out:
# 0.896975

# %%
test_count2=count_vec2.transform(clean_test_description)
test_count1=count_vec1.transform(news_test.title)
test_count=sparse.hstack((test_count1,test_count2))

# %%
clf1 = MultinomialNB().fit(train_count,news_train["label"])

# %%
# Predicting the Test set results, find accuracy
y_pred = clf1.predict(test_count)

# %%
y_pred = pd.DataFrame(y_pred,columns=['label'])
frames=[news_test,y_pred]
result=pd.concat(frames,axis=1)
result
# Out:
#                                                     title  \
# 0       Wall St. Bears Claw Back Into the Black (Reuters)
# 1       Carlyle Looks Toward Commercial Aerospace (Reu...
# 2         Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3       Iraq Halts Oil Exports from Main Southern Pipe...
# 4       Oil prices soar to all-time record, posing new...
# 5             Stocks End Up, But Near Year Lows (Reuters)
# 6                    Money Funds Fell in Latest Week (AP)
# 7       Fed minutes show dissent over inflation (USATO...
# 8                                 Safety Net (Forbes.com)
# 9                 Wall St. Bears Claw Back Into the Black
# 10                  Oil and Economy Cloud Stocks' Outlook
# 11                 No Need for OPEC to Pump More-Iran Gov
# 12              Non-OPEC Nations Should Up Output-Purnomo
# 13                  Google IPO Auction Off to Rocky Start
# 14               Dollar Falls Broadly on Record Trade Gap
# 15                                  Rescuing an Old Saver
# 16                           Kids Rule for Back-to-School
# 17              In a Down Market, Head Toward Value Funds
# 18                        US trade deficit swells in June
# 19                      Shell 'could be target for Total'
# 20                       Google IPO faces Playboy slip-up
# 21                         Eurozone economy keeps growing
# 22                               Expansion slows in Japan
# 23                        Rand falls on shock SA rate cut
# 24                       Car prices down across the board
# 25                      South Korea lowers interest rates
# 26                        Google auction begins on Friday
# 27                        HP shares tumble on profit news
# 28                       Mauritian textile firm cuts jobs
# 29                        Chad seeks refugee aid from IMF
# ...                                                   ...
# 119970                  Mortaza enjoys moment to remember
# 119971          EU agrees to membership talks with Turkey
# 119972   Bosnia Serb PM Resigns, Rejects Western Pressure
# 119973     North Korea says US steps up espionage flights
# 119974     Russia to hold Yukos auction despite US ruling
# 119975               Utah Routs Pittsburgh in Fiesta Bowl
# 119976          Stocks to Hold Up, But Anxiety Over Drugs
# 119977             Despite Mega-Deals, Small Mergers Rule
# 119978          Wal-Mart Dec. Sales Still Seen Up 1-3 Pct
# 119979            Sabotage Stops Iraq's North Oil Exports
# 119980                    Corporate Cost-Cutters Miss Out
# 119981  Murdoch will shell out \$44 mil. for Manhattan...
# 119982  AU Says Sudan Begins Troop Withdrawal from Dar...
# 119983  Insurgents Attack Iraq Election Offices (Reuters)
# 119984  Syria Redeploys Some Security Forces in Lebano...
# 119985         Security Scare Closes British Airport (AP)
# 119986      Iraqi Judges Start Quizzing Saddam Aides (AP)
# 119987  Musharraf says won't quit as army chief (Reuters)
# 119988  Navy to go on PR 'offensive' to repair battere...
# 119989  NBA Wrap: Wade, O'Neal Carry Heat to 7th Strai...
# 119990  Barack Obama Gets  #36;1.9 Million Book Deal (AP)
# 119991            Rauffer Beats Favorites to Win Downhill
# 119992        Iraqis Face Winter Shivering by Candlelight
# 119993  AU Says Sudan Begins Troop Withdrawal from Darfur
# 119994    Syria Redeploys Some Security Forces in Lebanon
# 119995  Pakistan's Musharraf Says Won't Quit as Army C...
# 119996                  Renteria signing a top-shelf deal
# 119997                    Saban not going to Dolphins yet
# 119998                                  Today's NFL games
# 119999                       Nets get Carter from Raptors
#
#                                               description     label
# 0       Reuters - Short-sellers, Wall Street's dwindli...  Business
# 1       Reuters - Private investment firm Carlyle Grou...  Business
# 2       Reuters - Soaring crude prices plus worries\ab...  Business
# 3       Reuters - Authorities have halted oil export\f...     World
# 4       AFP - Tearaway world oil prices, toppling reco...  Business
# 5       Reuters - Stocks ended slightly higher on Frid...  Business
# 6       AP - Assets of the nation's retail money marke...  Business
# 7       USATODAY.com - Retail sales bounced back a bit...  Business
# 8       Forbes.com - After earning a PH.D. in Sociolog...  Business
# 9        NEW YORK (Reuters) - Short-sellers, Wall Stre...  Business
# 10       NEW YORK (Reuters) - Soaring crude prices plu...  Business
# 11       TEHRAN (Reuters) - OPEC can do nothing to dou...  Business
# 12       JAKARTA (Reuters) - Non-OPEC oil exporters sh...  Business
# 13       WASHINGTON/NEW YORK (Reuters) - The auction f...  Business
# 14       NEW YORK (Reuters) - The dollar tumbled broad...  Business
# 15      If you think you may need to help your elderly...  Business
# 16      The purchasing power of kids is a big part of ...  Sci/Tech
# 17      There is little cause for celebration in the s...  Business
# 18      The US trade deficit has exploded 19 to a reco...  Business
# 19      Oil giant Shell could be bracing itself for a ...  Business
# 20      The bidding gets underway for Google's public ...  Business
# 21      Official figures show the 12-nation eurozone e...  Business
# 22      Economic growth in Japan slows down as the cou...  Business
# 23      Interest rates are trimmed to 7.5 by the South...  Business
# 24      The cost of buying both new and second hand ca...  Business
# 25      South Korea's central bank cuts interest rates...  Business
# 26      An auction of shares in Google, the web search...  Business
# 27      Hewlett-Packard shares fall after disappointin...  Business
# 28      One of the oldest textile operators on the Ind...  Business
# 29      Chad asks the IMF for a loan to pay for lookin...     World
# ...                                                   ...       ...
# 119970  Bangladesh fast bowler Mashrafe bin Mortaza wa...    Sports
# 119971  HAMISH ROBERTSON: In an historic decision, the...     World
# 119972  Bosnian Serb Prime Minister Dragan Mikerevic s...     World
# 119973  SEOUL, South Korea North Korea says America ha...     World
# 119974  MOSCOW - Russia said on Friday it would go ahe...  Business
# 119975   TEMPE, Ariz. (Sports Network) - Alex Smith th...    Sports
# 119976   NEW YORK (Reuters) - U.S. stocks should hold ...  Business
# 119977   Philadelphia (Reuters) - Despite the euphoria...  Business
# 119978   CHICAGO (Reuters) - Wal-Mart Stores Inc. &lt;...  Business
# 119979   BAGHDAD (Reuters) - Saboteurs blew up Iraq's ...     World
# 119980   CHICAGO (Reuters) - One of the mantras of glo...  Business
# 119981  NEW YORK -- Rupert Murdoch, the billionaire CE...  Business
# 119982  Reuters - The African Union said on Saturday t...     World
# 119983  Reuters - Insurgents have launched attacks\on ...     World
# 119984  Reuters - Syria, under intense pressure to qui...     World
# 119985  AP - Police arrested a Libyan man and blew up ...     World
# 119986  AP - Iraqi judges on Saturday started interrog...     World
# 119987  Reuters - Pakistani President Pervez Musharraf...     World
# 119988  Canadian Press - HALIFAX (CP) - They have beco...     World
# 119989   NEW YORK (Reuters) - Dwyane Wade scored 25 po...    Sports
# 119990  AP - U.S. Sen.-elect Barack Obama, whose 1995 ...  Sci/Tech
# 119991   VAL GARDENA, Italy (Reuters) - Max Rauffer be...    Sports
# 119992   BAGHDAD (Reuters) - As if the daily struggle ...     World
# 119993   ABUJA (Reuters) - The African Union said on S...     World
# 119994   BEIRUT (Reuters) - Syria, under intense press...     World
# 119995   KARACHI (Reuters) - Pakistani President Perve...     World
# 119996  Red Sox general manager Theo Epstein acknowled...    Sports
# 119997  The Miami Dolphins will put their courtship of...    Sports
# 119998  PITTSBURGH at NY GIANTS Time: 1:30 p.m. Line: ...    Sports
# 119999  INDIANAPOLIS -- All-Star Vince Carter was trad...    Sports
#
# [120000 rows x 3 columns]

# %%
result.to_csv("news-test.csv", sep='\t')
